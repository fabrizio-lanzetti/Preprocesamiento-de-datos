# %% [markdown]
# <a href="https://colab.research.google.com/github/fabrizio-lanzetti/Preprocesamiento-de-datos/blob/main/encuesta_preprocesamiento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Procesamiento de datos "ENCUESTA ESTUDIANTIL"

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\fabri\OneDrive\Desktop\Nueva carpeta\encuestra_instituto.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 45 columns):
#  #   Column                                                                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                                                                              --------------  -----
#  0   Marca temporal                                                                                                                                                                      214 non-null    object
#  1   Género (registrado al nacer)                                                                                                                                                        214 non-null    object
# ...

# %%
df1 = df.iloc[:, :22]
df2 = df.iloc[:,22:46]

# %% [markdown]
# # Vamos a dividir el dataframe en 2 partes para trabajar mas comodos

# %% [markdown]
# ## Columnas Originales y Nuevas Editadas del df1
#
# | **#** | **Columna Original**                                                                                             | **Columna Editada**                              |
# |-------|-------------------------------------------------------------------------------------------------------------------|--------------------------------------------------|
# | 0     | Marca temporal                                                                                                     | Marca_Temporal                                  |                              |
# | 1     | Género (registrado al nacer)                                                                                       | Genero_Nacer                                    |
# | 2     | ¿Cómo te consideras/autopercibes?                                                                                  | Autopercepcion                                   |
# | 3     | Nacionalidad                                                                                                       | Nacionalidad                                    |
# | 4     | ¿Te reconoces/consideras indígena o descendiente de pueblos originarios?                                           | Indigena_O_Descendiente                         |
# | 5     | Edad (en números)                                                                                                  | Edad                                            |
# | 6     | Estado civil                                                                                                       | Estado_Civil                                    |
# | 7     | Localidad de residencia durante el año académico                                                                   | Localidad_Residencia                            |
# | 8     | ¿Realizás alguna actividad física o deporte regularmente?                                                          | Actividad_Fisica                                |
# | 9    | ¿Tienes alguna condición, dificultad o limitación que requiera adaptaciones pedagógicas o edilicias?               | Condiciones_Limitaciones                        |
# | 10    | ¿Padeces ansiedad, depresión u otra afección mental?                                                                | Afecciones_Mentales                             |
# | 11    | ¿A qué distancia se encuentra el lugar donde residís del Instituto?                                                | Distancia_Instituto                             |
# | 12    | ¿Qué medio de transporte utilizás habitualmente para llegar al Instituto?                                          | Medio_Transporte                                |
# | 13    | ¿Cuánto tiempo en promedio te toma llegar de tu domicilio al Instituto?                                            | Tiempo_Traslado                                  |
# | 14    | ¿Cómo financias tus gastos de movilidad?                                                                             | Financiamiento_Movilidad                        |
# | 15    | ¿Trabajás?                                                                                                         | Trabajas                                         |
# | 16    | En tu trabajo te desempeñás como... (en caso de tener más de un trabajo responder en base al que te reporte mayor ingreso) | Desempeno_Laboral                                |
# | 17    | ¿A qué te dedicás?                                                                                                 | Actividad_Profesional                           |
# | 18    | ¿Dispones de cobertura de obra social por tu trabajo?                                                              | Obra_Social_Trabajo                             |
# | 19    | ¿Cuántas horas trabajás semanalmente?                                                                              | Horas_Trabajo                                   |
# | 20    | Tus horarios son:                                                                                                  | Horarios_Trabajo                                 |
# | 21    | ¿Disponés de alguna beca para financiar tus estudios?                                                              | Beca_Estudios                                    |

# %%
columnas_reemplazo = {
    'Marca temporal': 'Marca_Temporal',
    'Dirección de correo electrónico': 'Correo_Electronico',
    'Género (registrado al nacer)': 'Genero_Nacer',
    '¿Cómo te consideras/autopercibes?': 'Autopercepcion',
    'Nacionalidad': 'Nacionalidad',
    '¿Te reconoces/consideras indígena o descendiente de pueblos originarios?': 'Indigena_O_Descendiente',
    'Edad (en números)': 'Edad',
    'Estado civil': 'Estado_Civil',
    'Localidad de residencia durante el año académico': 'Localidad_Residencia',
    '¿Realizás alguna actividad física o deporte regularmente?': 'Actividad_Fisica',
    '¿Tienes alguna condición, dificultad o limitación que requiera adaptaciones pedagógicas o edilicias?': 'Condiciones_Limitaciones',
    '¿Padeces ansiedad, depresión u otra afección mental?': 'Afecciones_Mentales',
    '¿A qué distancia se encuentra el lugar donde residís del Instituto?': 'Distancia_Instituto',
    '¿Qué medio de transporte utilizás habitualmente para llegar al Instituto?': 'Medio_Transporte',
    '¿Cuánto tiempo en promedio te toma llegar de tu domicilio al Instituto?': 'Tiempo_Traslado',
    '¿Cómo financias tus gastos de movilidad?': 'Financiamiento_Movilidad',
    '¿Trabajás?': 'Trabajas',
    'En tu trabajo te desempeñás como... (en caso de tener más de un trabajo responder en base al que te reporte mayor ingreso)': 'Desempeno_Laboral',
    '¿A qué te dedicás?': 'Actividad_Profesional',
    '¿Dispones de cobertura de obra social por tu trabajo?': 'Obra_Social_Trabajo',
    '¿Cuántas horas trabajás semanalmente?': 'Horas_Trabajo',
    'Tus horarios son:': 'Horarios_Trabajo',
    '¿Disponés de alguna beca para financiar tus estudios?': 'Beca_Estudios'
}

df1.rename(columns=columnas_reemplazo, inplace=True)


df1.head()
# Out:
#             Marca_Temporal      Genero_Nacer Autopercepcion Nacionalidad  \
# 0  2024-05-29 09:34:28.466  Mujer / Femenino          Mujer  Argentino/a
# 1  2024-05-29 09:35:20.150  Mujer / Femenino          Mujer  Argentino/a
# 2  2024-05-29 09:38:48.713  Mujer / Femenino          Mujer  Argentino/a
# 3  2024-05-29 09:41:36.380  Mujer / Femenino          Mujer  Argentino/a
# 4  2024-05-29 09:46:56.746  Mujer / Femenino          Mujer  Argentino/a
#
#   Indigena_O_Descendiente  Edad              Estado_Civil  \
# 0                      No  27.0                 Soltero/a
# 1                      No  18.0                 Soltero/a
# 2                      No  20.0                 Soltero/a
# 3                      No  18.0                       NaN
# 4                      No  21.0  En pareja/Unión de hecho
#
#   Localidad_Residencia                 Actividad_Fisica  \
# 0            Barrancas                               No
# 1            Larrechea                               No
# ...

# %% [markdown]
# # Columnas Originales y Nuevas Editadas del df2
#
# | **#** | **Columna Original**                                                                                             | **Columna Editada**                               |
# |-------|-------------------------------------------------------------------------------------------------------------------|---------------------------------------------------|
# | 0     | Carrera/as en las que estás inscripto/a                                                                            | Carreras_Inscripcion                             |
# | 1     | Año en que ingresaste a la carrera. (Ej. Si este es tu primer año contestar 2024)                                  | Ano_Ingreso_Carrera                              |
# | 2     | Estás inscripto/a para cursar espacios correspondientes ¿a qué año del diseño curricular?                         | Ano_Curricular                                    |
# | 3     | Cantidad de miembros de tu hogar de residencia (en números)                                                        | Miembros_Hogar                                    |
# | 4     | Cantidad de hijo/as                                                                                                 | Cantidad_Hijos                                    |
# | 5     | Máximo nivel educativo del padre                                                                                    | Nivel_Educativo_Padre                            |
# | 6     | Máximo nivel educativo de la madre                                                                                  | Nivel_Educativo_Madre                            |
# | 7     | ¿En qué año egresaste de la escuela secundaria?                                                                    | Ano_Egreso_Secundaria                             |
# | 8     | La escuela secundaria de la que egresaste es de gestión:                                                           | Gestion_Escuela                                   |
# | 9     | ¿Cursaste otra carrera antes de este año?                                                                          | Cursaste_Otra_Carrera                            |
# | 10    | ¿Qué carrera/s cursaste previamente? (Si es más de una, responder por la más reciente)                             | Carrera_Previa                                    |
# | 11    | ¿En qué institución realizaste esos estudios?                                                                     | Institucion_Estudio                               |
# | 12    | ¿Completaste tus estudios?                                                                                        | Estudios_Completados                              |
# | 13    | ¿Cuáles son los medios tecnológicos de los que disponés para tus estudios?                                         | Medios_Tecnologicos_Estudios                      |
# | 14    | Los dispositivos que utilizás son:                                                                                 | Dispositivos_Usados                               |
# | 15    | ¿Con qué posibilidades de conectividad contás?                                                                     | Conectividad                                      |
# | 16    | ¿Desde dónde te conectás a wi fi habitualmente?                                                                    | Conexión_Wifi                                     |
# | 17    | ¿Qué calidad considerás que tiene tu conexión?                                                                     | Calidad_Conexion                                  |
# | 18    | ¿Considerás que te sería posible cursar materias en el turno mañana?                                               | Cursar_Mañana                                     |
# | 19    | ¿Considerás que una modificación en el horario de funcionamiento del Instituto durante este año dificultaría tu asistencia al mismo? | Modificacion_Horario_Instituto                    |
# | 20    | ¿Cuáles considerás que serían las principales dificultades para tu asistencia durante el turno matutino?          | Dificultades_Turno_Matutino                       |
# | 21    | Para cerrar el relevamiento nos interesaría conocer cuáles son, desde tu punto de vista, los principales problemas o aspectos a mejorar en nuestra institución | Problemas_Aspectos_Institucion                    |
# | 22    | ¿Hay algo más que quieras agregar, que pueda mejorar esta encuesta?                                                | Sugerencias_Encuesta                              |

# %%
# Diccionario con las columnas originales como claves y las nuevas como valores
columnas_reemplazo = {
    'Carrera/as en las que estás inscripto/a': 'Carreras_Inscripcion',
    'Año en que ingresaste a la carrera. (Ej. Si este es tu primer año contestar 2024)': 'Ano_Ingreso_Carrera',
    'Estás inscripto/a para cursar espacios correspondientes ¿a qué año del diseño curricular?': 'Ano_Curricular',
    'Cantidad de miembros de tu hogar de residencia (en números)': 'Miembros_Hogar',
    'Cantidad de hijo/as': 'Cantidad_Hijos',
    'Máximo nivel educativo del padre': 'Nivel_Educativo_Padre',
    'Máximo nivel educativo de la madre': 'Nivel_Educativo_Madre',
    '¿En qué año egresaste de la escuela secundaria?': 'Ano_Egreso_Secundaria',
    'La escuela secundaria de la que egresaste es de gestión:': 'Gestion_Escuela',
    '¿Cursaste otra carrera antes de este año?': 'Cursaste_Otra_Carrera',
    '¿Qué carrera/s cursaste previamente? (Si es más de una, responder por la más reciente)': 'Carrera_Previa',
    '¿En qué institución realizaste esos estudios?': 'Institucion_Estudio',
    '¿Completaste tus estudios?': 'Estudios_Completados',
    '¿Cuáles son los medios tecnológicos de los que disponés para tus estudios?': 'Medios_Tecnologicos_Estudios',
    'Los dispositivos que utilizás son:': 'Dispositivos_Usados',
    '¿Con qué posibilidades de conectividad contás?': 'Conectividad',
    '¿Desde dónde te conectás a wi fi habitualmente?': 'Conexión_Wifi',
    '¿Qué calidad considerás que tiene tu conexión?': 'Calidad_Conexion',
    '¿Considerás que te sería posible cursar materias en el turno mañana?': 'Cursar_Mañana',
    '¿Considerás que una modificación en el horario de funcionamiento del Instituto durante este año dificultaría tu asistencia al mismo?': 'Modificacion_Horario_Instituto',
    '¿Cuáles considerás que serían las principales dificultades para tu asistencia durante el turno matutino?': 'Dificultades_Turno_Matutino',
    'Para cerrar el relevamiento nos interesaría conocer cuáles son, desde tu punto de vista, los principales problemas o aspectos a mejorar en nuestra institución': 'Problemas_Aspectos_Institucion',
    '¿Hay algo más que quieras agregar, que pueda mejorar esta encuesta?': 'Sugerencias_Encuesta'
}

# Reemplaza las columnas en el DataFrame utilizando el diccionario
df2.rename(columns=columnas_reemplazo, inplace=True)

# Verifica los primeros registros para asegurarte de que los cambios fueron aplicados
print(df2.head())
# Out:
#          Carreras_Inscripcion  Ano_Ingreso_Carrera Ano_Curricular  \
# 0  Prof. en Educación Inicial               2022.0         3º año
# 1  Prof. en Educación Inicial               2024.0         1º año
# 2  Prof. en Educación Inicial               2024.0         1º año
# 3  Prof. en Educación Inicial               2024.0            NaN
# 4  Prof. en Educación Inicial               2024.0         1º año
#
#    Miembros_Hogar Cantidad_Hijos  Nivel_Educativo_Padre  \
# 0             2.0              1    Primario Incompleto
# 1             4.0              0  Secundario Incompleto
# 2             1.0              0                  Ns/Nc
# 3             7.0              0  Secundario Incompleto
# 4             3.0              1  Secundario Incompleto
#
#    Nivel_Educativo_Madre  Ano_Egreso_Secundaria Gestion_Escuela  \
# 0     Terciario Completo                   2015         Pública
# 1      Primario Completo                   2023         Pública
# ...

# %% [markdown]
# # Reemplzado de nulos para analisis df1

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Marca_Temporal            214 non-null    object
#  1   Genero_Nacer              214 non-null    object
#  2   Autopercepcion            214 non-null    object
#  3   Nacionalidad              214 non-null    object
#  4   Indigena_O_Descendiente   210 non-null    object
#  5   Edad                      212 non-null    float64
#  6   Estado_Civil              213 non-null    object
#  7   Localidad_Residencia      214 non-null    object
#  8   Actividad_Fisica          214 non-null    object
#  9   Condiciones_Limitaciones  213 non-null    object
#  10  Afecciones_Mentales       214 non-null    object
#  11  Distancia_Instituto       212 non-null    object
#  12  Medio_Transporte          214 non-null    object
# ...

# %%
df1.loc[df1["Trabajas"] == "Sí", "Desempeno_Laboral"] = df1.loc[df1["Trabajas"] == "Sí", "Desempeno_Laboral"].fillna("No aclara")

# %%
df1["Desempeno_Laboral"] = df1["Desempeno_Laboral"].fillna("No trabaja")

# %%
df1.loc[df1["Trabajas"] == "Sí", "Actividad_Profesional"] = df1.loc[df1["Trabajas"] == "Sí", "Actividad_Profesional"].fillna("No aclara")

# %%
df1["Actividad_Profesional"] = df1["Actividad_Profesional"].fillna("No trabaja")

# %%
df1.loc[df1["Trabajas"] == "Sí", "Obra_Social_Trabajo"] = df1.loc[df1["Trabajas"] == "Sí", "Obra_Social_Trabajo"].fillna("No tiene/No Aclara")

# %%
df1["Obra_Social_Trabajo"] = df1["Obra_Social_Trabajo"].fillna("No trabaja")

# %%
df1.loc[df1["Trabajas"] == "Sí", "Horas_Trabajo"] = df1.loc[df1["Trabajas"] == "Sí", "Horas_Trabajo"].fillna("No Aclara")

# %%
df1["Horas_Trabajo"] = df1["Horas_Trabajo"].fillna("No trabaja")

# %%
df1.loc[df1["Trabajas"] == "Sí", "Horarios_Trabajo"] = df1.loc[df1["Trabajas"] == "Sí", "Horarios_Trabajo"].fillna("No Aclara")

# %%
df1["Horarios_Trabajo"] = df1["Horarios_Trabajo"].fillna("No trabaja")

# %%
print("Moda Indigena_O_Descendiente: ",df1["Indigena_O_Descendiente"].mode())
print("Moda edad",df1["Edad"].mode())
print("Moda Distancia_instituto",df1["Distancia_Instituto"].mode())
print("Moda Financiamiento_Movilidad",df1["Financiamiento_Movilidad"].mode())
print("Moda Beca_Estudioos",df1["Beca_Estudios"].mode())
# Out:
# Moda Indigena_O_Descendiente:  0    No
# Name: Indigena_O_Descendiente, dtype: object
# Moda edad 0    18.0
# Name: Edad, dtype: float64
# Moda Distancia_instituto 0    0-10 kms.
# Name: Distancia_Instituto, dtype: object
# Moda Financiamiento_Movilidad 0    No tengo gastos de movilidad
# Name: Financiamiento_Movilidad, dtype: object
# Moda Beca_Estudioos 0    No cuento con ninguna beca
# Name: Beca_Estudios, dtype: object

# %%
df1["Indigena_O_Descendiente"] = df1["Indigena_O_Descendiente"].fillna("No")
df1["Estado_Civil"] = df1["Estado_Civil"].fillna("No aclara")
df1["Edad"] = df1["Edad"].fillna(18)
df1["Condiciones_Limitaciones"] = df1["Condiciones_Limitaciones"].fillna("No aclara")
df1["Distancia_Instituto"] = df1["Distancia_Instituto"].fillna("0-10 kms")
df1["Financiamiento_Movilidad"] = df1["Financiamiento_Movilidad"].fillna("No tengo gastos de movilidad")
df1["Beca_Estudios"] = df1["Beca_Estudios"].fillna("No cuento con ninguna beca")

# %%
df1.head()
# Out:
#             Marca_Temporal      Genero_Nacer Autopercepcion Nacionalidad  \
# 0  2024-05-29 09:34:28.466  Mujer / Femenino          Mujer  Argentino/a
# 1  2024-05-29 09:35:20.150  Mujer / Femenino          Mujer  Argentino/a
# 2  2024-05-29 09:38:48.713  Mujer / Femenino          Mujer  Argentino/a
# 3  2024-05-29 09:41:36.380  Mujer / Femenino          Mujer  Argentino/a
# 4  2024-05-29 09:46:56.746  Mujer / Femenino          Mujer  Argentino/a
#
#   Indigena_O_Descendiente  Edad              Estado_Civil  \
# 0                      No  27.0                 Soltero/a
# 1                      No  18.0                 Soltero/a
# 2                      No  20.0                 Soltero/a
# 3                      No  18.0                 No aclara
# 4                      No  21.0  En pareja/Unión de hecho
#
#   Localidad_Residencia                 Actividad_Fisica  \
# 0            Barrancas                               No
# 1            Larrechea                               No
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Marca_Temporal            214 non-null    object
#  1   Genero_Nacer              214 non-null    object
#  2   Autopercepcion            214 non-null    object
#  3   Nacionalidad              214 non-null    object
#  4   Indigena_O_Descendiente   214 non-null    object
#  5   Edad                      214 non-null    float64
#  6   Estado_Civil              214 non-null    object
#  7   Localidad_Residencia      214 non-null    object
#  8   Actividad_Fisica          214 non-null    object
#  9   Condiciones_Limitaciones  214 non-null    object
#  10  Afecciones_Mentales       214 non-null    object
#  11  Distancia_Instituto       214 non-null    object
#  12  Medio_Transporte          214 non-null    object
# ...

# %% [markdown]
# ### Ya tenemos toda la primer parte resuelta. Ahora vamos a exportar a csv

# %%
df1.to_csv('encuestaP1.csv', index=False)

# %% [markdown]
# # Reemplzado de nulos para analisis df2

# %%
df2.rename(columns={'¿Considerás que una modificación en el horario de funcionamiento del Instituto durante este año (comenzando las clases desde el turno mañana) dificultaría tu asistencia al mismo?': 'Modificacion_Horario_Instituto'}, inplace=True)

# %%
df2.head(10)
# Out:
#          Carreras_Inscripcion  Ano_Ingreso_Carrera Ano_Curricular  \
# 0  Prof. en Educación Inicial               2022.0         3º año
# 1  Prof. en Educación Inicial               2024.0         1º año
# 2  Prof. en Educación Inicial               2024.0         1º año
# 3  Prof. en Educación Inicial               2024.0            NaN
# 4  Prof. en Educación Inicial               2024.0         1º año
# 5  Prof. en Educación Inicial               2024.0         1º año
# 6  Prof. en Educación Inicial               2024.0         1º año
# 7  Prof. en Educación Inicial               2024.0         1º año
# 8  Prof. en Educación Inicial               2014.0         4º año
# 9  Prof. en Educación Inicial               2024.0         1º año
#
#    Miembros_Hogar Cantidad_Hijos     Nivel_Educativo_Padre  \
# 0             2.0              1       Primario Incompleto
# 1             4.0              0     Secundario Incompleto
# 2             1.0              0                     Ns/Nc
# ...

# %%
df2["Cursaste_Otra_Carrera"].value_counts()
# Out:
# Cursaste_Otra_Carrera
# No    141
# Sí     73
# Name: count, dtype: int64

# %%
print("Moda año curricular",df2["Ano_Curricular"].mode())
print("Moda Miembros_Hogar",df2["Miembros_Hogar"].mode())
print("Moda Cantidad_Hijos",df2["Cantidad_Hijos"].mode())
print("Moda Carreras_Inscripcion",df2["Carreras_Inscripcion"].mode())
print("Moda Nivel_Educativo_Padre",df2["Nivel_Educativo_Padre"].mode())
print("Moda Nivel_Educativo_Madre",df2["Nivel_Educativo_Madre"].mode())
# Out:
# Moda año curricular 0    1º año
# Name: Ano_Curricular, dtype: object
# Moda Miembros_Hogar 0    4.0
# Name: Miembros_Hogar, dtype: float64
# Moda Cantidad_Hijos 0    0
# Name: Cantidad_Hijos, dtype: object
# Moda Carreras_Inscripcion 0    Prof. en Educación Inicial
# Name: Carreras_Inscripcion, dtype: object
# Moda Nivel_Educativo_Padre 0    Secundario Completo
# Name: Nivel_Educativo_Padre, dtype: object
# Moda Nivel_Educativo_Madre 0    Secundario Completo
# Name: Nivel_Educativo_Madre, dtype: object

# %%
df2["Carreras_Inscripcion"] = df2["Carreras_Inscripcion"].fillna("Prof. en Educación Inicial")
df2["Ano_Curricular"] = df2["Ano_Curricular"].fillna("1º año")
df2["Miembros_Hogar"] = df2["Miembros_Hogar"].fillna(4.0)
df2["Cantidad_Hijos"] = df2["Cantidad_Hijos"].fillna(0)
df2["Nivel_Educativo_Padre"] = df2["Nivel_Educativo_Padre"].fillna("Secundario Completo")
df2["Nivel_Educativo_Madre"] = df2["Nivel_Educativo_Madre"].fillna("Secundario Completo")
df2["Dificultades_Turno_Matutino"] = df2["Dificultades_Turno_Matutino"].fillna("No aclara")
df2["Problemas_Aspectos_Institucion"] = df2["Problemas_Aspectos_Institucion"].fillna("No aclara")
df2["Sugerencias_Encuesta"] = df2["Sugerencias_Encuesta"].fillna("No aclara")

# %%
df2.loc[df2["Cursaste_Otra_Carrera"] == "Sí", "Carrera_Previa"]
cursaste_si = df2.loc[df2["Cursaste_Otra_Carrera"] == "Sí", "Carrera_Previa"]


df2.loc[df2["Cursaste_Otra_Carrera"] == "Sí", "Carrera_Previa"] = df2.loc[df2["Cursaste_Otra_Carrera"] == "Sí", "Carrera_Previa"].fillna("No aclara")

# %%
df2["Carrera_Previa"] = df2["Carrera_Previa"].fillna("Sin carrera previa")

# %%
df2.loc[df2["Cursaste_Otra_Carrera"] == "Sí", "Institucion_Estudio"] = df2.loc[df2["Cursaste_Otra_Carrera"] == "Sí", "Institucion_Estudio"].fillna("No aclara")
df2["Institucion_Estudio"] = df2["Institucion_Estudio"].fillna("Sin carrera previa")

# %%
df2.loc[df2["Cursaste_Otra_Carrera"] == "Sí", "Estudios_Completados"] = df2.loc[df2["Cursaste_Otra_Carrera"] == "Sí","Estudios_Completados"].fillna("No aclara")
df2["Estudios_Completados"] = df2["Estudios_Completados"].fillna("Sin carrera previa")

# %%
df2[["Cursaste_Otra_Carrera","Carrera_Previa","Institucion_Estudio","Estudios_Completados"]]
# Out:
#     Cursaste_Otra_Carrera                Carrera_Previa  \
# 0                      No            Sin carrera previa
# 1                      No            Sin carrera previa
# 2                      Sí      Profesorado de biología
# 3                      Sí  Tec. En Higiene y Seguridad
# 4                      No            Sin carrera previa
# ..                    ...                           ...
# 209                    No            Sin carrera previa
# 210                    Sí             Ingeniería civil
# 211                    No            Sin carrera previa
# 212                    Sí                    Psicología
# 213                    Sí                     No aclara
#
#                Institucion_Estudio Estudios_Completados
# 0               Sin carrera previa   Sin carrera previa
# 1               Sin carrera previa   Sin carrera previa
# 2                             Isp6                   No
# 3                              UNL                   No
# ...

# %%
df2["Problemas_Aspectos_Institucion"] = df2["Problemas_Aspectos_Institucion"].replace(".", "No aclara")

# %%
df2["Sugerencias_Encuesta"] = df2["Sugerencias_Encuesta"].replace(".","No aclara")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Carreras_Inscripcion            214 non-null    object
#  1   Ano_Ingreso_Carrera             213 non-null    float64
#  2   Ano_Curricular                  214 non-null    object
#  3   Miembros_Hogar                  214 non-null    float64
#  4   Cantidad_Hijos                  214 non-null    object
#  5   Nivel_Educativo_Padre           214 non-null    object
#  6   Nivel_Educativo_Madre           214 non-null    object
#  7   Ano_Egreso_Secundaria           214 non-null    int64
#  8   Gestion_Escuela                 214 non-null    object
#  9   Cursaste_Otra_Carrera           214 non-null    object
#  10  Carrera_Previa                  214 non-null    object
#  11  Institucion_Estudio             214 non-null    object
# ...

# %%
df2.to_csv("encuestaP2.csv",index=False)

# %% [markdown]
# # Union de df1 y df2 y exportacion de datos

# %%
df2.head()
# Out:
#          Carreras_Inscripcion  Ano_Ingreso_Carrera Ano_Curricular  \
# 0  Prof. en Educación Inicial               2022.0         3º año
# 1  Prof. en Educación Inicial               2024.0         1º año
# 2  Prof. en Educación Inicial               2024.0         1º año
# 3  Prof. en Educación Inicial               2024.0         1º año
# 4  Prof. en Educación Inicial               2024.0         1º año
#
#    Miembros_Hogar Cantidad_Hijos  Nivel_Educativo_Padre  \
# 0             2.0              1    Primario Incompleto
# 1             4.0              0  Secundario Incompleto
# 2             1.0              0                  Ns/Nc
# 3             7.0              0  Secundario Incompleto
# 4             3.0              1  Secundario Incompleto
#
#    Nivel_Educativo_Madre  Ano_Egreso_Secundaria Gestion_Escuela  \
# 0     Terciario Completo                   2015         Pública
# 1      Primario Completo                   2023         Pública
# ...

# %%
df1.head()
# Out:
#             Marca_Temporal      Genero_Nacer Autopercepcion Nacionalidad  \
# 0  2024-05-29 09:34:28.466  Mujer / Femenino          Mujer  Argentino/a
# 1  2024-05-29 09:35:20.150  Mujer / Femenino          Mujer  Argentino/a
# 2  2024-05-29 09:38:48.713  Mujer / Femenino          Mujer  Argentino/a
# 3  2024-05-29 09:41:36.380  Mujer / Femenino          Mujer  Argentino/a
# 4  2024-05-29 09:46:56.746  Mujer / Femenino          Mujer  Argentino/a
#
#   Indigena_O_Descendiente  Edad              Estado_Civil  \
# 0                      No  27.0                 Soltero/a
# 1                      No  18.0                 Soltero/a
# 2                      No  20.0                 Soltero/a
# 3                      No  18.0                 No aclara
# 4                      No  21.0  En pareja/Unión de hecho
#
#   Localidad_Residencia                 Actividad_Fisica  \
# 0            Barrancas                               No
# 1            Larrechea                               No
# ...

# %%
df_combined = pd.concat([df1, df2], axis=1)
df_combined.to_csv("encuestra_procesada.csv",index=False)

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 45 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Marca_Temporal                  214 non-null    object
#  1   Genero_Nacer                    214 non-null    object
#  2   Autopercepcion                  214 non-null    object
#  3   Nacionalidad                    214 non-null    object
#  4   Indigena_O_Descendiente         214 non-null    object
#  5   Edad                            214 non-null    float64
#  6   Estado_Civil                    214 non-null    object
#  7   Localidad_Residencia            214 non-null    object
#  8   Actividad_Fisica                214 non-null    object
#  9   Condiciones_Limitaciones        214 non-null    object
#  10  Afecciones_Mentales             214 non-null    object
#  11  Distancia_Instituto             214 non-null    object
# ...

# %%
df_combined.head()
# Out:
#             Marca_Temporal      Genero_Nacer Autopercepcion Nacionalidad  \
# 0  2024-05-29 09:34:28.466  Mujer / Femenino          Mujer  Argentino/a
# 1  2024-05-29 09:35:20.150  Mujer / Femenino          Mujer  Argentino/a
# 2  2024-05-29 09:38:48.713  Mujer / Femenino          Mujer  Argentino/a
# 3  2024-05-29 09:41:36.380  Mujer / Femenino          Mujer  Argentino/a
# 4  2024-05-29 09:46:56.746  Mujer / Femenino          Mujer  Argentino/a
#
#   Indigena_O_Descendiente  Edad              Estado_Civil  \
# 0                      No  27.0                 Soltero/a
# 1                      No  18.0                 Soltero/a
# 2                      No  20.0                 Soltero/a
# 3                      No  18.0                 No aclara
# 4                      No  21.0  En pareja/Unión de hecho
#
#   Localidad_Residencia                 Actividad_Fisica  \
# 0            Barrancas                               No
# 1            Larrechea                               No
# ...
